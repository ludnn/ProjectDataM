# %% [markdown]
# Project Goal:
# The main goal of the project is to build a classification model that accurately assigns a given house to one of four price quartiles using its features. The output of this project will help users understand which category a property belongs to based on its specifications.

# %% [markdown]
# Dataset Source:
# The dataset was obtained from Kaggle:
# House Price Prediction Treated Dataset(https://www.kaggle.com/datasets/aravinii/house-price-prediction-treated-dataset/data)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f897aba4-e209-4906-a0b2-8ec60c433d15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f897aba4-e209-4906-a0b2-8ec60c433d15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd, numpy as np
df = pd.read_csv("Dataset.csv")

# %%
print("Number of columns:", df.shape[1])
print("Data types of columns:")
print(df.dtypes)
# Out:
# Number of columns: 14
# Data types of columns:
# date                  object
# price                  int64
# bedrooms               int64
# grade                  int64
# has_basement            bool
# living_in_m2         float64
# renovated               bool
# nice_view               bool
# perfect_condition       bool
# real_bathrooms         int64
# has_lavatory            bool
# single_floor            bool
# month                  int64
# quartile_zone          int64
# dtype: object

# %% [markdown]
# The dataset has 14 columns (features + class label) ,
# The dataset includes both numeric and categorical attributes

# %%
print("Number of objects (instances):", df.shape[0])
# Out:
# Number of objects (instances): 6700

# %% [markdown]
# The dataset contains 6700 rows (instances)

# %%
print("Class attribute: quartile_zone")
print("Unique class labels:", df['quartile_zone'].unique())
print("Class distribution:")
print(df['quartile_zone'].value_counts())
# Out:
# Class attribute: quartile_zone
# Unique class labels: [2 3 1 4]
# Class distribution:
# quartile_zone
# 2    1954
# 3    1724
# 1    1642
# 4    1380
# Name: count, dtype: int64

# %% [markdown]
# The class attribute is **quartile_zone**.
# It has 4 possible values: {1, 2, 3, 4}.
# The distribution shows that each label has a sufficient number of instances, which makes the dataset suitable for classification tasks.

# %%
df.head()
# Out:
#         date   price  bedrooms  grade  has_basement  living_in_m2  renovated  \
# 0  9/26/2014  305000         2      1         False      76.18046      False
# 1  5/14/2014  498000         3      2          True     210.88981      False
# 2  3/23/2015  590000         2      4         False     262.91549      False
# 3  7/15/2014  775000         3      3         False     159.79316      False
# 4  4/14/2015  350000         2      1         False      92.90300      False
#
#    nice_view  perfect_condition  real_bathrooms  has_lavatory  single_floor  \
# 0      False               True               1         False          True
# 1      False              False               2          True          True
# 2      False              False               2          True         False
# 3      False              False               1          True         False
# 4      False              False               1          True          True
#
#    month  quartile_zone
# ...

# %% [markdown]
# A sample of the first 5 rows is displayed to show the raw dataset structure
